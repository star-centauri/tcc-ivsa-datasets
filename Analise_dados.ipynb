# %% [markdown]
# # Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %% [markdown]
# Para acessar meus arquivos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def carregar_dataframes(xlsx):
    df_global = {}

    # Itera sobre todas as abas do arquivo Excel
    for sheet_name in xlsx.sheet_names:
      # Lê cada aba e armazena no dicionário
      df = xlsx.parse(sheet_name)

      # Verifica se a coluna "CIDADE" existe no DataFrame
      if 'CIDADE' in df.columns:
          # Remove o " (RJ)" da coluna "CIDADE"
          df['CIDADE'] = df['CIDADE'].str.replace(' (RJ)', '', regex=False)

      # Armazena o DataFrame no dicionário
      df_global[sheet_name] = df

    return df_global

# %% [markdown]
# # Analisando Outliers

# %% [markdown]
# ## indicadores de criticidade

# %%
xlxs_criticidade = pd.ExcelFile('/content/drive/MyDrive/BCC/BRUNA_LIMA/DATASETS/IVSA/IND_CRITICIDADE.xlsx')

# %%
dfs_criticidade = carregar_dataframes(xlxs_criticidade)

# %%
dfs_criticidade['Ind1'].head(10)
# Out:
#                CIDADE  VALOR
# 0      Angra dos Reis   8297
# 1             Aperibé    541
# 2            Araruama   6583
# 3               Areal    606
# 4  Armação dos Búzios   1621
# 5     Arraial do Cabo   1517
# 6      Barra do Piraí   5815
# 7         Barra Mansa   9827
# 8        Belford Roxo  27469
# 9          Bom Jardim   1312

# %% [markdown]
# ### Indicador 1

# %% [markdown]
# Pela análise tem outliers. Tratar esse indicador antes de normalizar

# %%
# Selecionar dataframe de teste
df = dfs_criticidade['Ind1']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind1")
plt.xlabel("Valor")
plt.show()

# %% [markdown]
# ### Indicador 2

# %% [markdown]
# Pela análise não tem outliers

# %%
# Selecionar dataframe de teste
df = dfs_criticidade['Ind2']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind1")
plt.xlabel("Valor")
plt.show()

# %% [markdown]
# ### Indicador 3

# %% [markdown]
# Possui outliers. Será necessário escalonar

# %%
# Selecionar dataframe de teste
df = dfs_criticidade['Ind3']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind1")
plt.xlabel("Valor")
plt.show()

# %% [markdown]
# ### Indicador 4

# %% [markdown]
# Muitos outliers, necessário escalonar

# %%
# Selecionar dataframe de teste
df = dfs_criticidade['Ind4']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind1")
plt.xlabel("Valor")
plt.show()

# %% [markdown]
# ### Indicador 5

# %%
# Selecionar dataframe de teste
df = dfs_criticidade['Ind5']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind1")
plt.xlabel("Valor")
plt.show()

# %% [markdown]
# ### Indicador 6

# %%
# Selecionar dataframe de teste
df = dfs_criticidade['Ind6']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind6")
plt.xlabel("Valor")
plt.show()

# %% [markdown]
# ### Indicador 7

# %%
# Selecionar dataframe de teste
df = dfs_criticidade['Ind7']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind7")
plt.xlabel("Valor")
plt.show()

# %% [markdown]
# ### Indicador 8

# %%
# Selecionar dataframe de teste
df = dfs_criticidade['Ind8']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind8")
plt.xlabel("Valor")
plt.show()

# %% [markdown]
# ## Indicadores de Suportabilidade

# %%
xlxs_suportabilidade = pd.ExcelFile('/content/drive/MyDrive/BCC/BRUNA_LIMA/DATASETS/IVSA/IND_SUPORTABILIDADE.xlsx')

# %%
dfs_suportabilidade = carregar_dataframes(xlxs_suportabilidade)

# %%
dfs_suportabilidade['Ind9'].head(10)
# Out:
#                CIDADE  VALOR
# 0      Angra dos Reis    406
# 1             Aperibé    168
# 2            Araruama   1522
# 3               Areal     59
# 4  Armação dos Búzios     48
# 5     Arraial do Cabo     46
# 6      Barra do Piraí    631
# 7         Barra Mansa    171
# 8        Belford Roxo  20252
# 9          Bom Jardim    173

# %% [markdown]
# ### Indicador 9

# %%
# Selecionar dataframe de teste
df = dfs_suportabilidade['Ind9']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind9")
plt.xlabel("Valor")
plt.show()

# %% [markdown]
# ### Indicador 10

# %%
# Selecionar dataframe de teste
df = dfs_suportabilidade['Ind10']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind10")
plt.xlabel("Valor")
plt.show()

# %% [markdown]
# ### Indicador 11

# %%
# Selecionar dataframe de teste
df = dfs_suportabilidade['Ind11']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind11")
plt.xlabel("Valor")
plt.show()

# %% [markdown]
# ### Indicador 12

# %%
# Selecionar dataframe de teste
df = dfs_suportabilidade['Ind12']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind12")
plt.xlabel("Valor")
plt.show()

# %% [markdown]
# ### Indicador 13

# %%
# Selecionar dataframe de teste
df = dfs_suportabilidade['Ind13']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind13")
plt.xlabel("Valor")
plt.show()

# %% [markdown]
# ## Indicadores de Histórico de Incidentes

# %%
xlxs_historico = pd.ExcelFile('/content/drive/MyDrive/BCC/BRUNA_LIMA/DATASETS/IVSA/IND_HISTORICO.xlsx')

# %%
dfs_historico = carregar_dataframes(xlxs_historico)

# %%
dfs_historico['Ind14'].head(10)
# Out:
#                     CIDADE  VALOR
# 0           Angra dos Reis     19
# 1                  Aperibé      7
# 2                 Araruama      2
# 3                    Areal      2
# 4       Armação dos Búzios      1
# 5          Arraial do Cabo     14
# 6           Barra do Piraí     13
# 7              Barra Mansa      7
# 8             Belford Roxo      4
# 9  Bom Jesus do Itabapoana     20

# %% [markdown]
# ### Indicador 14

# %%
# Selecionar dataframe de teste
df = dfs_historico['Ind14']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind14")
plt.xlabel("Valor")
plt.show()# Selecionar dataframe de test

# %% [markdown]
# ### Indicador 15

# %%
# Selecionar dataframe de teste
df = dfs_historico['Ind15']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind15")
plt.xlabel("Valor")
plt.show()# Selecionar dataframe de test

# %% [markdown]
# ### Indicador 16

# %%
# Selecionar dataframe de teste
df = dfs_historico['Ind16']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind16")
plt.xlabel("Valor")
plt.show()# Selecionar dataframe de test

# %% [markdown]
# ### Indicador 17

# %%
# Selecionar dataframe de teste
df = dfs_historico['Ind17']

df['Z-SCORE'] = zscore(df['VALOR'])

# Definir outliers como valores com Z-score > 3 ou < -3
outlier_threshold = 3
df['OUTLIER'] = df['Z-SCORE'].abs() > outlier_threshold

# Criar Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["VALOR"])
plt.title("Boxplot dos Valores por Município (Outliers visíveis) - Ind17")
plt.xlabel("Valor")
plt.show()# Selecionar dataframe de test
